# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
#from config2 import g_key
g_key = "AIzaSyAtDHsE9EVbe6Zso80xBSLrobjUIqveoNk"

# %%
data = pd.read_csv("/Users/brianroberts1/Documents/GitHub/python_api_challenge/WeatherPy/weather_output.csv")
data
# Out:
#      Unnamed: 0             City Country  Latitude  Longitude  Max Temp (F)  \
# 0             0        Tcholliré      CM      8.40      14.17        298.83
# 1             1    Katima Mulilo     NaN    -17.50      24.27        297.93
# 2             2           Albany      US     42.60     -73.97        277.59
# 3             3  Bambous Virieux      MU    -20.34      57.76        292.15
# 4             4          Rikitea      PF    -23.12    -134.97        297.41
# ..          ...              ...     ...       ...        ...           ...
# 562         562       Porto-Novo      BJ      6.50       2.60        301.15
# 563         563       Sovetskaya      RU     44.78      41.17        288.15
# 564         564        Micheweni      TZ     -4.97      39.83        298.31
# 565         565        Caibarién      CU     22.52     -79.47        301.15
# 566         566           Dayong      CN     25.02     118.29        293.15
#
#      Humidity (%)  Cloudiness (%)  Wind Speed (mph)
# ...

# %%
# Remove duplicate index column
del data['Unnamed: 0']
data
# Out:
#                 City Country  Latitude  Longitude  Max Temp (F)  Humidity (%)  \
# 0          Tcholliré      CM      8.40      14.17        298.83            52
# 1      Katima Mulilo     NaN    -17.50      24.27        297.93            22
# 2             Albany      US     42.60     -73.97        277.59            78
# 3    Bambous Virieux      MU    -20.34      57.76        292.15            82
# 4            Rikitea      PF    -23.12    -134.97        297.41            67
# ..               ...     ...       ...        ...           ...           ...
# 562       Porto-Novo      BJ      6.50       2.60        301.15            83
# 563       Sovetskaya      RU     44.78      41.17        288.15             1
# 564        Micheweni      TZ     -4.97      39.83        298.31            81
# 565        Caibarién      CU     22.52     -79.47        301.15            74
# 566           Dayong      CN     25.02     118.29        293.15            64
#
# ...

# %%
# Download and Save to VacationPy
gmaps.configure(api_key = g_key)

locations = data[["Latitude", "Longitude"]]
humidity = data["Humidity (%)"]

# %%
# Create HeatMap
fig = gmaps.figure(center = (45,-45), zoom_level=3)

heatLayer = gmaps.heatmap_layer(locations, weights = humidity, max_intensity = 25, point_radius = 0.2)

fig.add_layer(heatLayer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Define climate factors of interest
clouds = data["Cloudiness (%)"]
temp = data["Max Temp (F)"]
wind = data["Wind Speed (mph)"]

# %%
# Dataset temperatures appear to be in a strange unit. Must review dataset for reasons why...
spec_data = data.loc[(temp>200) & (temp<300)]
spec_data = spec_data.loc[(clouds==0) & (wind<10)]
spec_data
# Out:
#             City Country  Latitude  Longitude  Max Temp (F)  Humidity (%)  \
# 2         Albany      US     42.60     -73.97        277.59            78
# 4        Rikitea      PF    -23.12    -134.97        297.41            67
# 9       Hermanus      ZA    -34.42      19.23        287.04            81
# 18   Broken Hill      AU    -31.95     141.43        286.15            76
# 34     Cape Town      ZA    -33.93      18.42        289.26            55
# ..           ...     ...       ...        ...           ...           ...
# 549       Gawler      AU    -34.60     138.73        288.15            74
# 554     Karratha      AU    -20.74     116.85        293.71            80
# 555    Sotouboua      TG      8.57       0.98        298.15            69
# 558  Chhuīkhadān      IN     21.53      80.98        293.58            47
# 566       Dayong      CN     25.02     118.29        293.15            64
#
#      Cloudiness (%)  Wind Speed (mph)
# 2                 0              2.60
# ...

# %%
# Drop any rows that don't contain all three conditions. 
spec_data = spec_data.dropna()
spec_data
# Out:
#             City Country  Latitude  Longitude  Max Temp (F)  Humidity (%)  \
# 2         Albany      US     42.60     -73.97        277.59            78
# 4        Rikitea      PF    -23.12    -134.97        297.41            67
# 9       Hermanus      ZA    -34.42      19.23        287.04            81
# 18   Broken Hill      AU    -31.95     141.43        286.15            76
# 34     Cape Town      ZA    -33.93      18.42        289.26            55
# ..           ...     ...       ...        ...           ...           ...
# 549       Gawler      AU    -34.60     138.73        288.15            74
# 554     Karratha      AU    -20.74     116.85        293.71            80
# 555    Sotouboua      TG      8.57       0.98        298.15            69
# 558  Chhuīkhadān      IN     21.53      80.98        293.58            47
# 566       Dayong      CN     25.02     118.29        293.15            64
#
#      Cloudiness (%)  Wind Speed (mph)
# 2                 0              2.60
# ...

# %% [markdown]
# Hotel Map
#
# Store into variable named hotel_df.
# Add a "Hotel Name" column to the DataFrame.
# Set parameters to search for hotels with 5000 meters.
# Hit the Google Places API for each city's coordinates.
# Store the first Hotel result into the DataFrame.
# Plot markers on top of the heatmap.

# %%
# Save ideal locations as new dataframe
hotel_df = spec_data
hotel_df.head()
# Out:
#            City Country  Latitude  Longitude  Max Temp (F)  Humidity (%)  \
# 2        Albany      US     42.60     -73.97        277.59            78
# 4       Rikitea      PF    -23.12    -134.97        297.41            67
# 9      Hermanus      ZA    -34.42      19.23        287.04            81
# 18  Broken Hill      AU    -31.95     141.43        286.15            76
# 34    Cape Town      ZA    -33.93      18.42        289.26            55
#
#     Cloudiness (%)  Wind Speed (mph)
# 2                0              2.60
# 4                0              2.51
# 9                0              0.89
# 18               0              5.70
# 34               0              6.20

# %%
# Due to API payments requirements,...
#...the final call to the API to create the map was not feasible.

#Set parameters for our map
params = {"radius":5000, 
         "keyword":"hotel",
         "key":g_key}

for i in range (len(hotel_df)):
    lat = hotel_df.loc[i]["Latitude"]
    lng = hotel_df.loc[i]["Longitude"]
    params["location"] = f"{lat}, {lng}"
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    response = requests.get(url, params = params).json()
    
    try:
        hotel_df.loc[]
